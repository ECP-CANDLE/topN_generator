# %%
from sklearn.model_selection import ShuffleSplit
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
df = pd.read_parquet('top21.parquet').sample(frac=1.)
df
# Out:
#            CELL       DRUG     AUC   GE_A1BG   GE_A1CF    GE_A2M  GE_A2ML1  \
# 355529  CCL_562   Drug_688  0.9099 -1.218680 -0.268673  0.173404  2.530088
# 114968  CCL_712    Drug_25  0.9922  0.572614  0.576304 -0.460626 -0.372810
# 52523   CCL_834  Drug_1481  0.9051 -0.286099 -0.268673 -0.416899 -0.372810
# 91069    CCL_11   Drug_210  0.6898 -1.186598  2.743773 -0.429121 -0.006940
# 16342   CCL_956   Drug_115  0.7639 -1.509534  3.171594 -0.438762  0.028975
# ...         ...        ...     ...       ...       ...       ...       ...
# 241718   CCL_79    Drug_46  0.9989  0.766517 -0.339088 -0.291187 -0.232185
# 411200  CCL_878   Drug_997  0.5901  0.669566 -0.268673  3.217836 -0.181962
# 17359   CCL_869   Drug_116  0.5729  1.338993 -0.278733 -0.487954 -0.372810
# 340928  CCL_449   Drug_662  0.8607  1.172790 -0.278733 -0.274789 -0.362765
# 13498   CCL_770   Drug_112  0.5909  0.646482 -0.268673 -0.356776 -0.292453
#
#         GE_A3GALT2  GE_A4GALT  GE_A4GNT  ...   dd_SRW10   dd_TSRW10  \
# 355529    1.768047   0.817096 -0.427922  ...  10.519889   88.830250
# 114968    0.353417  -0.402071  1.448252  ...  10.586357   72.249630
# 52523    -0.408307  -0.896328 -0.427922  ...  10.115247   73.856926
# 91069    -0.310406   0.753503 -0.158447  ...   9.972780   73.420520
# 16342    -0.408307  -1.363126 -0.427922  ...  10.743567   63.496136
# ...            ...        ...       ...  ...        ...         ...
# 241718   -0.408307   0.196529 -0.219458  ...  11.363973  124.092190
# 411200   -0.408307  -0.978704  0.093238  ...  11.127130  109.728424
# 17359    -0.408307   0.493083  0.232213  ...  10.979053   91.811554
# 340928    0.244599  -1.346651 -0.427922  ...   9.757941   65.049950
# 13498    -0.408307  -0.089042 -0.149970  ...  10.716527   84.600700
#
#             dd_MW     dd_AMW  dd_WPath  dd_WPol  dd_Zagreb1  dd_Zagreb2  \
# 355529  516.16090   8.602682    5134.0       60         202         237
# 114968  368.13510   7.218335     911.0       47         132         168
# 52523   331.11210   8.490053    1475.0       38         134         158
# 91069   362.12128   8.230029    1541.0       35         128         147
# 16342   371.10050   8.434102    1584.0       60         156         198
# ...           ...        ...       ...      ...         ...         ...
# 241718  904.34320   7.863854   18175.0      129         366         451
# 411200  729.40880   6.571250    9767.0      102         304         375
# 17359   507.18933   7.684687    3502.0       78         206         262
# 340928  257.02590  10.281035     628.0       25          96         112
# 13498   489.13922   8.152320    3147.0       63         186         229
#
#         dd_mZagreb1  dd_mZagreb2
# 355529    11.444445     8.250000
# 114968     7.902778     4.500000
# 52523      6.638889     5.444445
# 91069      8.138889     5.500000
# 16342     10.895833     5.666666
# ...             ...          ...
# 241718    19.506945    14.944445
# 411200    15.145833    10.916667
# 17359     12.597222     8.354167
# 340928     5.166666     3.888889
# 13498     10.375000     7.055555
#
# [411304 rows x 19359 columns]

# %% [markdown]
# ## Partitions

# %%
idx_vec = df.index.to_numpy(copy=True)
idx_vec
# Out:
# array([355529, 114968,  52523, ...,  17359, 340928,  13498])

# %%
selector = ShuffleSplit(
    n_splits=1,
    train_size=0.8,
    test_size=0.1,
    random_state=2022,
)
splits = selector.split(idx_vec)
train_idx, val_idx = next(splits)
tr_vl_idx = np.asarray(train_idx.tolist() + val_idx.tolist())

# %%
train_idx, len(train_idx)
# Out:
# (array([208810, 107585, 204275, ..., 201139, 168391,  55777]), 329043)

# %% [markdown]
# ## Feature Selection

# %%
# select lincs1000 genes
lincs1k = pd.read_csv('lincs1000', sep='\t', header=0)
lincs1k_cols = set(map(lambda x: f"GE_{x}", lincs1k.columns.to_list()))
not_in_lincs_cols = set(filter(lambda x: x.startswith("GE_"), df.columns)) - lincs1k_cols

# %%
df.drop(labels=not_in_lincs_cols, axis=1, inplace=True)
df
# Out:
#            CELL       DRUG     AUC   GE_AARS  GE_ABCB6  GE_ABCC5  GE_ABCF1  \
# 355529  CCL_562   Drug_688  0.9099 -0.098415  0.603366  1.365327  0.886353
# 114968  CCL_712    Drug_25  0.9922 -1.274175  0.588435  1.221479  0.764272
# 52523   CCL_834  Drug_1481  0.9051  0.614967 -0.553804 -0.186184  0.921233
# 91069    CCL_11   Drug_210  0.6898 -1.565972  0.000769  0.376519 -0.690784
# 16342   CCL_956   Drug_115  0.7639 -1.089224 -0.352233 -0.134809  0.223626
# ...         ...        ...     ...       ...       ...       ...       ...
# 241718   CCL_79    Drug_46  0.9989 -0.574003 -2.390346 -0.556080 -0.369340
# 411200  CCL_878   Drug_997  0.5901 -0.349420  0.976647 -0.114259  0.380588
# 17359   CCL_869   Drug_116  0.5729 -0.455106  0.088239 -0.288933 -0.229818
# 340928  CCL_449   Drug_662  0.8607 -0.904273  0.095704  1.540001 -0.090297
# 13498   CCL_770   Drug_112  0.5909  0.641388  0.588435  0.235088  0.415468
#
#         GE_ABCF3  GE_ABHD4  GE_ABHD6  ...   dd_SRW10   dd_TSRW10      dd_MW  \
# 355529  1.835916  0.162662 -2.475820  ...  10.519889   88.830250  516.16090
# 114968 -0.587969 -1.306221 -0.818018  ...  10.586357   72.249630  368.13510
# 52523   0.517663 -1.044744  0.330459  ...  10.115247   73.856926  331.11210
# 91069  -0.765157 -1.022898 -0.236833  ...   9.972780   73.420520  362.12128
# 16342   0.262517 -0.883244  0.630062  ...  10.743567   63.496136  371.10050
# ...          ...       ...       ...  ...        ...         ...        ...
# 241718 -0.758066  0.154972 -0.438521  ...  11.363973  124.092190  904.34320
# 411200  0.177468 -0.229552  1.269215  ...  11.127130  109.728424  729.40880
# 17359   0.517663  0.854806  0.929665  ...  10.979053   91.811554  507.18933
# 340928  2.027275 -2.321365  0.819810  ...   9.757941   65.049950  257.02590
# 13498   0.964168 -0.029600  1.379069  ...  10.716527   84.600700  489.13922
#
#            dd_AMW  dd_WPath  dd_WPol  dd_Zagreb1  dd_Zagreb2  dd_mZagreb1  \
# 355529   8.602682    5134.0       60         202         237    11.444445
# 114968   7.218335     911.0       47         132         168     7.902778
# 52523    8.490053    1475.0       38         134         158     6.638889
# 91069    8.230029    1541.0       35         128         147     8.138889
# 16342    8.434102    1584.0       60         156         198    10.895833
# ...           ...       ...      ...         ...         ...          ...
# 241718   7.863854   18175.0      129         366         451    19.506945
# 411200   6.571250    9767.0      102         304         375    15.145833
# 17359    7.684687    3502.0       78         206         262    12.597222
# 340928  10.281035     628.0       25          96         112     5.166666
# 13498    8.152320    3147.0       63         186         229    10.375000
#
#         dd_mZagreb2
# 355529     8.250000
# 114968     4.500000
# 52523      5.444445
# 91069      5.500000
# 16342      5.666666
# ...             ...
# 241718    14.944445
# 411200    10.916667
# 17359      8.354167
# 340928     3.888889
# 13498      7.055555
#
# [411304 rows x 2558 columns]

# %% [markdown]
# ## Build Uno AUC dataframe

# %%
# Rename cols to compatible to Uno
df.rename({'CELL': 'Sample', 'DRUG': 'Drug1'}, axis=1, inplace=True)

# %%
# masks
tr_mask = df.index.isin(train_idx)
vl_mask = df.index.isin(val_idx)
te_mask = ~df.index.isin(tr_vl_idx)

# %%
# build label
Y_train = df.iloc[tr_mask, :][['Sample', 'Drug1', 'AUC']].reset_index(drop=True)
Y_val = df.iloc[vl_mask, :][['Sample', 'Drug1', 'AUC']].reset_index(drop=True)
Y_test = df.iloc[te_mask, :][['Sample', 'Drug1', 'AUC']].reset_index(drop=True)

# %%
# cell features
col_cl = list(filter(lambda x: x.startswith("GE_"), df.columns))

x_train_0 = df.iloc[tr_mask, :][col_cl].reset_index(drop=True)
x_val_0 = df.iloc[vl_mask, :][col_cl].reset_index(drop=True)
x_test_0 = df.iloc[te_mask, :][col_cl].reset_index(drop=True)

# %%
x_train_0
# Out:
#          GE_AARS  GE_ABCB6  GE_ABCC5  GE_ABCF1  GE_ABCF3  GE_ABHD4  GE_ABHD6  \
# 0      -0.098415  0.603366  1.365327  0.886353  1.835916  0.162662 -2.475820
# 1      -1.274175  0.588435  1.221479  0.764272 -0.587969 -1.306221 -0.818018
# 2       0.614967 -0.553804 -0.186184  0.921233  0.517663 -1.044744  0.330459
# 3      -1.089224 -0.352233 -0.134809  0.223626  0.262517 -0.883244  0.630062
# 4       1.011290 -1.345159 -1.449997 -0.160058 -0.587969 -0.183410 -0.108958
# ...          ...       ...       ...       ...       ...       ...       ...
# 329038 -0.481528  0.984113  1.457802  1.165396  1.198052 -1.844554 -0.348640
# 329039 -0.574003 -2.390346 -0.556080 -0.369340 -0.758066  0.154972 -0.438521
# 329040 -0.349420  0.976647 -0.114259  0.380588  0.177468 -0.229552  1.269215
# 329041 -0.904273  0.095704  1.540001 -0.090297  2.027275 -2.321365  0.819810
# 329042  0.641388  0.588435  0.235088  0.415468  0.964168 -0.029600  1.379069
#
#          GE_ABL1  GE_ACAA1  GE_ACAT2  ...  GE_ZMIZ1  GE_ZMYM2  GE_ZNF131  \
# 0      -1.470567  2.483160 -0.025473  ...  0.784771  0.054667   1.597031
# 1      -0.444090  0.095332  1.235497  ...  1.358107  2.625690   1.835522
# 2      -0.799935 -0.268913  0.234422  ... -1.167898 -0.856878  -0.255862
# 3      -0.608326  2.725989  1.254749  ... -1.483649  1.036331   0.037666
# 4       0.336032 -0.403818  0.272925  ... -2.148387  0.545499  -0.072407
# ...          ...       ...       ...  ...       ...       ...        ...
# 329038  2.033141  0.108823  0.147790  ...  0.336072  0.849347   0.496303
# 329039  0.418151 -0.403818  0.648328  ... -0.985095  0.101413  -0.916299
# 329040  0.294973  0.769860 -0.824408  ... -0.087698  0.148159   0.221121
# 329041  0.171796  1.538821  0.898597  ...  1.707095  1.048017   1.523649
# 329042  1.595177 -0.268913  0.378808  ...  1.108831 -1.546380  -0.641116
#
#         GE_ZNF274  GE_ZNF318  GE_ZNF395  GE_ZNF451  GE_ZNF586  GE_ZNF589  \
# 0        0.758591  -0.945954  -0.397134   0.057486   1.324547  -1.962975
# 1       -0.031689   0.890347   1.186781   1.031985   0.822593   0.976140
# 2        0.334818  -1.185471  -0.354612  -0.562649   1.234452   0.523968
# 3       -1.165569   0.318166  -0.280200  -0.846140  -3.115815   0.050265
# 4        0.174471   1.622205   1.069848   0.801649   0.063226   0.427074
# ...           ...        ...        ...        ...        ...        ...
# 329038   1.182365   1.901642   0.102491   0.925676   1.350288   0.674692
# 329039  -0.558542   0.344779   0.474551  -0.403186   0.578051  -0.875610
# 329040  -0.627262  -0.387080  -1.396382  -0.810704  -0.297151   0.642394
# 329041   0.712778   3.179069  -0.471546   1.209166   2.444290   1.848185
# 329042  -0.318022   0.437925   0.017448  -1.041040  -0.142703   1.277587
#
#          GE_ZW10
# 0      -1.184192
# 1       2.968377
# 2       0.288728
# 3       0.146760
# 4       0.519426
# ...          ...
# 329038  0.572664
# 329039  0.129014
# 329040 -0.509843
# 329041 -1.752065
# 329042  0.306474
#
# [329043 rows x 942 columns]

# %%
# drug features
col_dr = list(filter(lambda x: x.startswith("dd_"), df.columns))

x_train_1 = df.iloc[tr_mask, :][col_dr].reset_index(drop=True)
x_val_1 = df.iloc[vl_mask, :][col_dr].reset_index(drop=True)
x_test_1 = df.iloc[te_mask, :][col_dr].reset_index(drop=True)

# %%
x_train_1
# Out:
#            dd_ABC   dd_ABCGG  dd_nAcid  dd_nBase  dd_SpAbs_A  dd_SpMax_A  \
# 0       30.002792  22.111973         0         0   49.796196    2.406517
# 1       17.955917  14.437097         0         0   28.621237    2.621543
# 2       19.856009  15.247416         0         0   33.322075    2.474047
# 3       21.589062  17.307938         0         0   33.643410    2.622182
# 4       26.403017  22.130955         0         0   41.330150    2.468933
# ...           ...        ...       ...       ...         ...         ...
# 329038  45.864094  36.531483         0         0   71.380844    2.727273
# 329039  52.686478  38.476750         0         1   89.640010    2.748132
# 329040  42.488075  26.499352         0         1   68.264770    2.652757
# 329041  14.280035  11.600451         0         0   23.430252    2.385046
# 329042  26.349987  20.005718         0         0   43.489075    2.576592
#
#         dd_SpDiam_A  dd_SpAD_A  dd_SpMAD_A  dd_LogEE_A  ...   dd_SRW10  \
# 0          4.799943  49.796196    1.310426    4.571155  ...  10.519889
# 1          5.192865  28.621237    1.300965    4.073557  ...  10.586357
# 2          4.812980  33.322075    1.332883    4.165300  ...  10.115247
# 3          5.244363  33.643410    1.246052    4.255863  ...  10.743567
# 4          4.936377  41.330150    1.215593    4.441976  ...  10.457746
# ...             ...        ...         ...         ...  ...        ...
# 329038     5.454546  71.380844    1.230704    5.000399  ...  11.459282
# 329039     5.284868  89.640010    1.337911    5.146177  ...  11.363973
# 329040     5.119367  68.264770    1.312784    4.922651  ...  11.127130
# 329041     4.742016  23.430252    1.301681    3.839144  ...   9.757941
# 329042     5.023607  43.489075    1.317851    4.451970  ...  10.716527
#
#          dd_TSRW10      dd_MW     dd_AMW  dd_WPath  dd_WPol  dd_Zagreb1  \
# 0        88.830250  516.16090   8.602682    5134.0       60         202
# 1        72.249630  368.13510   7.218335     911.0       47         132
# 2        73.856926  331.11210   8.490053    1475.0       38         134
# 3        63.496136  371.10050   8.434102    1584.0       60         156
# 4        83.520010  520.05950  10.197246    3364.0       53         178
# ...            ...        ...        ...       ...      ...         ...
# 329038   98.156990  807.34660   7.273393   12587.0      121         326
# 329039  124.092190  904.34320   7.863854   18175.0      129         366
# 329040  109.728424  729.40880   6.571250    9767.0      102         304
# 329041   65.049950  257.02590  10.281035     628.0       25          96
# 329042   84.600700  489.13922   8.152320    3147.0       63         186
#
#         dd_Zagreb2  dd_mZagreb1  dd_mZagreb2
# 0              237    11.444445     8.250000
# 1              168     7.902778     4.500000
# 2              158     6.638889     5.444445
# 3              198    10.895833     5.666666
# 4              206    13.625000     7.236111
# ...            ...          ...          ...
# 329038         403    23.951390    12.145833
# 329039         451    19.506945    14.944445
# 329040         375    15.145833    10.916667
# 329041         112     5.166666     3.888889
# 329042         229    10.375000     7.055555
#
# [329043 rows x 1613 columns]

# %%
with pd.HDFStore('top21_uno_v2.h5', "w") as store:
    store.put("y_train", Y_train, format="table")
    store.put("y_val", Y_val, format="table")
    store.put("y_test", Y_val, format="table")
    store.put("x_train_0", x_train_0, format="table")
    store.put("x_train_1", x_train_1, format="table")
    store.put("x_val_0", x_val_0, format="table")
    store.put("x_val_1", x_val_1, format="table")
    store.put("x_test_0", x_val_0, format="table")
    store.put("x_test_1", x_val_1, format="table")

    # model info
    cl_width = len(col_cl)
    dd_width = len(col_dr)
    store.put("model", pd.DataFrame())
    store.get_storer("model").attrs.input_features = OrderedDict(
        [("cell.rnaseq", "cell.rnaseq"), ("drug1.descriptors", "drug.descriptors")]
    )
    store.get_storer("model").attrs.feature_shapes = OrderedDict(
        [("cell.rnaseq", (cl_width,)), ("drug.descriptors", (dd_width,))]
    )
